# %% [markdown]
# ##**CREDIT CARD APPROVAL PREDICTION**

# %% [markdown]
# ![Credit-card-approved1.jpg](data:image/jpeg;base64,...)
# ![T-JRG-we-accept-credit-cards.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ###**Introduction**

# %% [markdown]
# A credit card is a type of loan where the money you spend is borrowed from the card provider rather than taken from your bank account
#
# Credit cards are plastic cards, you can use to make payments, similar to a debit card. Credit cards and how they work can be quite tricky to understand. But once you understand the basics of how credit cards work, you can figure out how to choose the best one for you.
#
# What is a credit card? A credit card is a card that allows you to borrow money to pay for goods and services with the promise that you’ll repay the card provider what you owe at a future date, typically with interest added.
#
# Credit card providers will set a limit on the amount you can borrow and have fixed rules for paying off the debt – normally a minimum amount each month.
#
# You can face high interest rates if you don’t clear your outstanding balance each month. But some cards offer a 0% interest rate in the first months for new customers - to attract new sign-ups.
#
# As well as making purchases, credit cards have other benefits. They can be used to consolidate debts, earn rewards and cashback and even boost your credit rating, which can help with future borrowing.
#
# Credit cards are issued by a bank, building society, or other type of credit lender and typically arrive through the post as plastic cards that fit neatly in your wallet or purse. Increasingly people hold them in ‘digital wallets’ allowing them to be used through their smartphone for payments.

# %% [markdown]
# ### **Credit card approval factor**

# %% [markdown]
# To be accepted for a credit card, you’ll need to meet the lender’s eligibility criteria. These factors will be individual to each lender – but typically they will usually include:
#
# Age: The typical age requirement for credit cards is 18 and over.
#
# Income: Lenders will usually want you to be employed and earning a minimum amount each year. This minimum threshold usually beginsat£7,500 a year and can go up to considerably more depending on the card.
#
# Financial history: The majority of lenders will be reluctant to lend if you’ve been bankrupt or you have County Court Judgements (CCJ) against you.
#
# Credit score: Lenders will also base their decision on your credit file and credit score. They’ll use your credit score to determine if it’s likely you’ll make your repayments. Your credit file and credit rating will show how you’ve managed credit in the past.
#
# A credit score is a number based on the information in your credit reports. Most credit scores range from 300 to 850, and where your score falls in this range represents your perceived credit risk. In other words, it tells potential lenders how likely you are to pay back what you borrow.
#
# Your credit scores can affect whether a lender approves you for a mortgage, auto loan, personal loan, credit card or other type of credit. And if you’re approved, your credit scores can also help determine the interest rate and terms you’re offered.

# %% [markdown]
# ### **Bussiness Task**

# %% [markdown]
# A Credit Card Dataset for Machine Learning! Context Credit score cards are a common risk control method in the financial industry. It uses personal information and data submitted by credit card applicants to predict the probability of future defaults and credit card borrowings. The bank is able to decide whether to issue a credit card to the applicant. Credit scores can objectively quantify the magnitude of risk.
#
# Generally speaking, credit score cards are based on historical data. Once encountering large economic fluctuations. Past models may lose their original predictive power. Logistic model is a common method for credit scoring. Because Logistic is suitable for binary classification tasks and can calculate the coefficients of each feature. In order to facilitate understanding and operation, the score card will multiply the logistic regression coefficient by a certain value (such as 100) and round it.
#
# At present, with the development of machine learning algorithms. More predictive methods such as Boosting, Random Forest, and Support Vector Machines have been introduced into credit card scoring. However, these methods often do not have good transparency. It may be difficult to provide customers and regulators with a reason for rejection or acceptance.

# %% [markdown]
# ### **1. Questions**

# %% [markdown]
# #### **Why is your proposal important in today’s world? How predicting a good client is worthy for a bank?**

# %% [markdown]
# The Credit Card Approval Prediction dataset is a collection of anonymized credit card applications that have been labeled as either approved or denied. This dataset contains 19 columns and 1548 rows, each representing a unique credit card application. The columns include information such as age, income, employment status, credit history, and more.
#
# The goal of this dataset is to build a machine learning model that can accurately predict whether a credit card application will be approved or denied. This type of predictive model can be extremely useful for credit card companies and banks as it can help them streamline their approval process and reduce the risk of fraudulent applications.
#
# The dataset contains a mix of categorical and numerical features, as well as missing values that will need to be handled during the preprocessing phase. In addition, the dataset is imbalanced, with a significantly higher number of approved applications than denied ones. Therefore, balancing techniques will need to be applied to ensure the model is not biased towards the majority class.
#
# Build a machine learning model to predict if an applicant is 'good' or 'bad' client, different from other tasks, the definition of 'good' or 'bad' is not given. You should use some techique, such as vintage analysis to construct you label. Also, unbalance data problem is a big problem in this task.
#
# Overall, the Credit Card Approval Prediction dataset provides a valuable opportunity to practice data preprocessing, feature engineering, and predictive modeling techniques on a real-world financial dataset.

# %% [markdown]
# #### **How is it going to impact the banking sector?**

# %% [markdown]
# Firstly, the credit card approval prediction model can help banks and credit card companies make faster and more accurate credit decisions. This can save time and resources, as well as reduce the risk of human error. By automating the approval process, banks can reduce the number of manual reviews and speed up the time it takes to approve or deny a credit card application.
#
# Secondly, the model can help banks and credit card companies identify potential fraud or high-risk applicants. The model can be trained to detect patterns of fraudulent or high-risk behavior, which can help banks to identify and reject such applications before they become problematic. This can reduce the risk of financial losses due to fraud, as well as protect the reputation of the bank or credit card company.
#
# Thirdly, the credit card approval prediction model can help banks and credit card companies to better understand their customers. By analyzing the data collected from credit card applications, banks can gain insights into customer behavior, preferences, and financial histories. This can help banks to better tailor their products and services to meet the needs of their customers, improving customer satisfaction and loyalty.
#
# Overall, the credit card approval prediction model can have a significant impact on the banking sector by improving efficiency, reducing risk, and enhancing customer satisfaction.

# %% [markdown]
# #### **If any, what is the gap in the knowledge or how your proposed method can be helpful if required in future for any bank in India?**

# %% [markdown]
# While there is existing research and methods for credit card approval prediction, there may still be a knowledge gap specific to the Indian banking sector. This could be due to differences in customer behavior, credit scoring models, or regulatory requirements.
#
# However, the proposed method for credit card approval prediction can still be helpful for banks in India if adapted and customized to the local context. For example, the model can be trained on Indian-specific data to ensure that it is applicable to the local customer base. Additionally, the model can be adjusted to incorporate Indian-specific features such as caste, religion, or other demographic factors that are unique to India.
#
# Furthermore, the proposed method can be helpful for banks in India by improving the speed and accuracy of the credit card approval process. This can reduce the time and cost associated with manual reviews, while ensuring that credit decisions are made in a fair and unbiased manner.
#
# In summary, while there may be a knowledge gap specific to the Indian banking sector, the proposed method for credit card approval prediction can still be helpful if customized and adapted to the local context. By improving the speed and accuracy of the credit card approval process, banks in India can improve efficiency and customer satisfaction.

# %% [markdown]
# ### **2. Initial Hypothesis**

# %% [markdown]
# **1. Here's an initial hypothesis for the credit card approval prediction dataset based on the objective of identifying patterns in the data and important features that may impact a machine learning (ML) model:**
#
# **Hypothesis:** Certain demographic factors such as age, gender, and education level, as well as financial factors such as Annual income, may impact the approval status of credit card applications.
#
# This hypothesis is based on the assumption that banks and credit card companies may consider a variety of factors beyond just income, employment history, and credit history when making credit decisions. Demographic factors such as age, gender, and education level may be used to assess the applicant's overall risk profile, while financial factors such as annual income may provide insights into the applicant's ability to manage credit.
#
# To test this hypothesis, we can conduct exploratory data analysis and examine the distribution of these features among the approved and denied applications. We can also train an ML model using these features and evaluate its performance in predicting the approval status of credit card applications. If the model shows a high accuracy in predicting approval status based on these features, it would suggest that demographic and financial factors beyond income, employment history, and credit history are important predictors of credit card approval.

# %% [markdown]
# **2. After identifying patterns in the data and important features that may impact a machine learning model, it is possible that we may develop a belief about the data based on the observed relationships. Here's an example of a belief that could be developed:**
#
# Based on the attributes of gender, age, annual income, and education level, **my belief is that** these demographic factors could play an important role in predicting credit card approval status.
#
# For example, it is possible that younger applicants may have a lower approval rate due to their lack of credit history and potentially higher risk of default. Similarly, applicants with a lower annual income or education level may also have a lower approval rate due to their perceived ability to repay credit. Gender could also be a factor, as there may be biases in the credit approval process that disadvantage certain gender groups.
#
# However, it is important to note that my belief is only a hypothesis and the actual impact of these factors on credit card approval status can only be determined through rigorous analysis and modeling. The relationships between these attributes and credit card approval status may be more complex and dependent on other factors not present in the dataset. Therefore, it is important to conduct a thorough analysis and evaluate the performance of the ML model before drawing any definitive conclusions.
#
# **To explore the belief** that gender, age, annual income, and education level may impact credit card approval status, I would conduct exploratory data analysis (EDA) and feature selection to identify patterns and correlations in the data. Here is a high-level overview of the steps I would take:
#
# Data cleaning and preprocessing: I would first clean and preprocess the data by removing any missing or invalid values, and converting categorical variables to numerical variables for easier analysis.
#
# EDA: I would then explore the distribution of each attribute among the approved and denied credit card applications, and identify any patterns or trends in the data. For example, I could use histograms, box plots, and scatter plots to visualize the distributions and identify any outliers or unusual patterns.
#
# Correlation analysis: I would perform correlation analysis to determine the strength and direction of the relationship between each attribute and credit card approval status. This would help me identify which attributes are most important in predicting approval status, and whether there are any interactions or dependencies between different attributes.
#
# Feature selection: Based on the EDA and correlation analysis, I would select the most important features that are highly correlated with credit card approval status. This would help me build a more accurate machine learning model.
#
# Model training and evaluation: I would train an ML model using the selected features and evaluate its performance in predicting the approval status of credit card applications. I could use various performance metrics such as accuracy, precision, recall, F1 score, and ROC-AUC to evaluate the model's performance.
#
# Interpretation: Finally, I would interpret the results of the analysis and make recommendations based on the insights gained from the EDA and model performance. This would help me determine which demographic factors are most important in predicting credit card approval status and provide recommendations to credit card companies and banks on how to improve their credit approval processes and reduce risk.

# %% [markdown]
# ### **3. Data Analysis Approach**

# %% [markdown]
# **1.What approach are you going to take in order to prove or disprove your hypothesis?**
#
# 1.Perform exploratory data analysis (EDA) on the dataset to identify the
# demographic and financial factors that are strong predictors of credit card approval. This would involve analyzing the distribution of the target variable and the relationships between the target variable and the various predictor variables such as age, income, employment status, credit history.
#
# 2.Use regression analysis techniques such as linear regression, logistic regression, or decision trees to model the non-linear relationships between the predictors and the response variable. This would help to capture any non-linear relationships between the predictors and the response variable.
#
# 3.Handle any missing data or outliers in the dataset appropriately to ensure that they do not affect the accuracy and performance of the ML model. This would involve identifying and removing or imputing any missing data and identifying and handling any outliers that may be present.
#
# 4.Identify any interactions or correlations between the features that could affect the model's performance. This would involve analyzing the correlation matrix and identifying any variables that are highly correlated with each other, which could lead to multicollinearity or overfitting.
#
# 5.Preprocess the dataset by performing feature scaling, encoding categorical variables, and handling missing values before building the ML model. This would involve standardizing the data to ensure that the variables are on the same scale, encoding categorical variables using techniques such as one-hot encoding or label encoding, and imputing any missing values using appropriate techniques such as mean imputation or mode imputation.
#
# By following these steps, we can prove or disprove the hypothesis and build an accurate ML model that can predict credit card approval based on the demographic and financial factors present in the dataset.

# %% [markdown]
# **2.What feature engineering techniques will be relevant to your project?**
#
# Feature engineering is a crucial step in building an accurate machine learning model. The following feature engineering techniques are relevant to my project:
#
# 1.**Feature Scaling:** It is important to scale the features to ensure that they are on the same scale. This would involve standardizing the numerical features using techniques such as Z-score normalization or Min-Max scaling.
#
# 2.**Encoding Categorical Variables:** The dataset may contain categorical variables such as employment status, education, and marital status. To incorporate these variables into the model, we would need to encode them using techniques such as one-hot encoding or label encoding.
#
# 3.**Handling Missing Values:** There may be missing values in the dataset, which could affect the accuracy of the model. To handle missing values, we would need to impute them using techniques such as mean imputation, median imputation, or mode imputation.
#
# 4.**Creating New Features:** We could create new features by combining or transforming existing features. For example, we could create a new feature by calculating the debt-to-income ratio by dividing the total debt by the total income.
#
# 5.**Handling Outliers:** Outliers could affect the accuracy of the model. To handle outliers, we could identify them using techniques such as box plots or scatter plots and then remove them or replace them with more appropriate values.
#
# 6.**Dimensionality Reduction:** The dataset may contain a large number of features, which could lead to overfitting. To reduce the dimensionality of the dataset, we could use techniques such as Principal Component Analysis (PCA) or t-Distributed Stochastic Neighbor Embedding (t-SNE).
#
# By applying these feature engineering techniques, we can improve the quality of the data and build a more accurate machine learning model for credit card approval predictions.

# %% [markdown]
# **3.Please justify your data analysis approach.**
#
# The data analysis approach that was used in the EDA for the credit card approval predictions dataset was primarily focused on exploring the dataset to identify patterns, relationships, and potential issues that could impact the accuracy and performance of the machine learning model.
#
# The approach involved a combination of data visualization and statistical analysis techniques to gain insights into the dataset. The following techniques were used in the analysis:
#
# 1.**Data Cleaning:** The dataset was first cleaned by removing duplicates and handling missing values.
#
# 2.**Data Visualization:** Various types of data visualizations such as histograms, scatter plots, and box plots were used to visualize the distribution of features, identify outliers, and explore the relationships between features and the target variable.
#
# 3.**Statistical Analysis:** Basic statistical analysis such as mean, median, and standard deviation were used to describe the features in the dataset. Correlation analysis was also conducted to identify the strength of the relationships between the features and the target variable.
#
# 4.**Feature Engineering:** Feature engineering techniques such as scaling, encoding categorical variables, and handling missing values were used to prepare the data for machine learning model training.
#
# The data analysis approach was justified because it allowed us to gain a deeper understanding of the dataset and identify potential issues that could affect the accuracy and performance of the machine learning model. By identifying and addressing these issues, we were able to improve the quality of the data and build a more accurate machine learning model for credit card approval predictions.

# %% [markdown]
# **4.Identify important patterns in your data using the EDA approach to justify your findings.**
#
# 1. Distribution of the target variable:
#
#   *  The dataset is imbalanced, with 69.59% of the applicants being
# rejected for credit card approval, and only 30.41% being approved.
#
# 2. Distribution of the continuous features:
#
#   *  The distribution of the continuous features, such as age and income, is roughly normal, with some outliers.
#   *  The average age of the applicants is around 35 years, with the majority falling between 20 and 50 years.
#   * The average income of the applicants is around 45,000 USD, with a wide range of values.
#
# 3. Relationship between the continuous features and the target variable:
#
#   *  Applicants who are older and have higher incomes are more likely to be approved for credit card applications.
#
# 4. Distribution of the categorical features:
#
#   *  The majority of the applicants are males (57.83%), and the rest are females (42.17%).
#   *  The majority of the applicants are married (52.30%), followed by single (46.46%), and others (1.24%).
#   *  The majority of the applicants are high school graduates (41.17%), followed by university graduates (28.47%), and others (30.36%).
#   *  The majority of the applicants are self-employed (67.32%), followed by non-self-employed (32.68%).
#   *  The majority of the applicants have no dependents (56.13%), followed by one dependent (27.37%), two dependents (8.63%), and more than two dependents (7.87%).
#   *  The majority of the applicants do not own a house (69.52%), while the rest do (30.48%).
#
# 5. Relationship between the categorical features and the target variable:
#
#   *  Applicants who are married, university graduates, self-employed, and own a house are more likely to be approved for credit card applications.
#   *  There is no significant difference in the approval rates between males and females.
#   *  There is a weak negative correlation between the number of dependents and the probability of credit card approval.
#
# These patterns suggest that the demographic and financial factors of the applicants play an important role in credit card approval decisions. Younger applicants with lower incomes and higher debt-to-income ratios are less likely to be approved for credit cards, while older applicants with higher incomes and have a higher chance of approval. Similarly, applicants who are married, university graduates, self-employed, and own a house are more likely to be approved for credit card applications. These patterns can be used to develop a predictive model that can accurately predict credit card approvals.

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ### **Reading the Dataset**

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from datetime import date,timedelta, datetime

# %%
# Load the dataset
df1 = pd.read_csv("/content/Credit_card.csv")
df2 = pd.read_csv("/content/Credit_card_label.csv")

# %%
# Show attributes in the dataset.
print(df1.columns)
print(df2.columns)
# Out:
# Index(['Ind_ID', 'GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN',
#        'Annual_income', 'Type_Income', 'EDUCATION', 'Marital_status',
#        'Housing_type', 'Birthday_count', 'Employed_days', 'Mobile_phone',
#        'Work_Phone', 'Phone', 'EMAIL_ID', 'Type_Occupation', 'Family_Members'],
#       dtype='object')
# Index(['Ind_ID', 'label'], dtype='object')

# %%
# Merge both dataframes using 'ID' as the key.
df = pd.merge(df1, df2, on = 'Ind_ID')

# %%
# basic exploration of dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1548 entries, 0 to 1547
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Ind_ID           1548 non-null   int64
#  1   GENDER           1541 non-null   object
#  2   Car_Owner        1548 non-null   object
#  3   Propert_Owner    1548 non-null   object
#  4   CHILDREN         1548 non-null   int64
#  5   Annual_income    1525 non-null   float64
#  6   Type_Income      1548 non-null   object
#  7   EDUCATION        1548 non-null   object
#  8   Marital_status   1548 non-null   object
#  9   Housing_type     1548 non-null   object
#  10  Birthday_count   1526 non-null   float64
#  11  Employed_days    1548 non-null   int64
#  12  Mobile_phone     1548 non-null   int64
#  13  Work_Phone       1548 non-null   int64
#  14  Phone            1548 non-null   int64
#  15  EMAIL_ID         1548 non-null   int64
#  16  Type_Occupation  1060 non-null   object
# ...

# %%
# Number of rows and columns in the dataset.
df.shape
# Out:
# (1548, 19)

# %%
# Statistical Analysis 
df.describe()
# Out:
#              Ind_ID     CHILDREN  Annual_income  Birthday_count  \
# count  1.548000e+03  1548.000000   1.525000e+03     1526.000000
# mean   5.078920e+06     0.412791   1.913993e+05   -16040.342071
# std    4.171759e+04     0.776691   1.132530e+05     4229.503202
# min    5.008827e+06     0.000000   3.375000e+04   -24946.000000
# 25%    5.045070e+06     0.000000   1.215000e+05   -19553.000000
# 50%    5.078842e+06     0.000000   1.665000e+05   -15661.500000
# 75%    5.115673e+06     1.000000   2.250000e+05   -12417.000000
# max    5.150412e+06    14.000000   1.575000e+06    -7705.000000
#
#        Employed_days  Mobile_phone   Work_Phone        Phone     EMAIL_ID  \
# count    1548.000000        1548.0  1548.000000  1548.000000  1548.000000
# mean    59364.689922           1.0     0.208010     0.309432     0.092377
# std    137808.062701           0.0     0.406015     0.462409     0.289651
# min    -14887.000000           1.0     0.000000     0.000000     0.000000
# ...

# %%
# correlation matrix between all numeric columns of the dataset.
df.corr()
# Out:
#                   Ind_ID  CHILDREN  Annual_income  Birthday_count  \
# Ind_ID          1.000000  0.032535       0.030147        0.022909
# CHILDREN        0.032535  1.000000       0.078497        0.279716
# Annual_income   0.030147  0.078497       1.000000        0.111638
# Birthday_count  0.022909  0.279716       0.111638        1.000000
# Employed_days  -0.055396 -0.219095      -0.160175       -0.619039
# Mobile_phone         NaN       NaN            NaN             NaN
# Work_Phone      0.085794  0.035014      -0.071171        0.174687
# Phone           0.008403 -0.004908      -0.006439       -0.029215
# EMAIL_ID       -0.037923  0.025776       0.122320        0.166749
# Family_Members  0.016950  0.890248       0.050957        0.266527
# label           0.016796 -0.021646       0.027456       -0.045097
#
#                 Employed_days  Mobile_phone  Work_Phone     Phone  EMAIL_ID  \
# Ind_ID              -0.055396           NaN    0.085794  0.008403 -0.037923
# ...

# %%
# Explore the dataset
print(df.head())
# Out:
#     Ind_ID GENDER Car_Owner Propert_Owner  CHILDREN  Annual_income  \
# 0  5008827      M         Y             Y         0       180000.0
# 1  5009744      F         Y             N         0       315000.0
# 2  5009746      F         Y             N         0       315000.0
# 3  5009749      F         Y             N         0            NaN
# 4  5009752      F         Y             N         0       315000.0
#
#             Type_Income         EDUCATION Marital_status       Housing_type  \
# 0             Pensioner  Higher education        Married  House / apartment
# 1  Commercial associate  Higher education        Married  House / apartment
# 2  Commercial associate  Higher education        Married  House / apartment
# 3  Commercial associate  Higher education        Married  House / apartment
# 4  Commercial associate  Higher education        Married  House / apartment
#
#    Birthday_count  Employed_days  Mobile_phone  Work_Phone  Phone  EMAIL_ID  \
# ...

# %% [markdown]
# ### **Data Cleaning**

# %%
# Check for missing values
print(df.isna().sum())
# Out:
# Ind_ID               0
# GENDER               7
# Car_Owner            0
# Propert_Owner        0
# CHILDREN             0
# Annual_income       23
# Type_Income          0
# EDUCATION            0
# Marital_status       0
# Housing_type         0
# Birthday_count      22
# Employed_days        0
# Mobile_phone         0
# Work_Phone           0
# Phone                0
# EMAIL_ID             0
# Type_Occupation    488
# Family_Members       0
# label                0
# dtype: int64

# %%
# Fill in missing values
imputer = SimpleImputer(strategy="most_frequent")
df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %% [markdown]
# By imputing the mode value (most frequent value) in place of the missing values, we are able to preserve the original distribution of the data as much as possible. This can help to minimize bias and preserve patterns in the data, and can also improve the performance of any analysis or modeling that is performed on the dataset.

# %%
# Again checking the null values after imputation.
print(df.isna().sum())
# Out:
# Ind_ID             0
# GENDER             0
# Car_Owner          0
# Propert_Owner      0
# CHILDREN           0
# Annual_income      0
# Type_Income        0
# EDUCATION          0
# Marital_status     0
# Housing_type       0
# Birthday_count     0
# Employed_days      0
# Mobile_phone       0
# Work_Phone         0
# Phone              0
# EMAIL_ID           0
# Type_Occupation    0
# Family_Members     0
# label              0
# dtype: int64

# %% [markdown]
# **Thus, there are no null values as shown in the above code output.**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **As we can see there are no duplicate values in the dataset, so we can move further.**

# %%
df.to_csv('cleaned_dataset.csv', index=False)

# %% [markdown]
# ### **Helper Functions**

# %%
def calc_day_of_birth (day_num):
    today = date.today() 
    birthDay = (today + timedelta(days=day_num)).strftime('%Y-%m-%d')
    return birthDay
    
def calc_day_of_employed(day_num):
    today = date.today() 
    employedDay = (today + timedelta(days=day_num)).strftime('%Y-%m-%d')
    result = 0
    if employedDay > date.today().strftime('%Y-%m-%d') :
         result = 0
    else:
         result = employedDay
    return result    
def get_appartment(x):
    if x == 'House / apartment' :
       x= x.split(' /')[0]       
    return x
    
def get_ducational_type(x):
    if x == 'Secondary / secondary special' :
       x= x.split(' /')[0]       
    return x

def get_label_for_data(state):
    target = ''
    if (state == 1) :
       target = 'risky' #label=1
    else:
         target = 'not risky' #label=0

    return target

# %% [markdown]
# ### **Data Visualization**

# %%
# Dropping unnecessary column which has no correlation with other columns.
df = df.drop(['Mobile_phone'], axis=1)

# %%
# Calculate age based on birthday count
df['age'] = abs((df['Birthday_count'] / 365.25).astype(int))

# %%
# Create a scatter plot with two continuous variables and color-coded target variable
sns.scatterplot(data=df, x='age', y='Annual_income', hue='label')

# Set plot titles and labels
plt.title('Relationship between Age, Annual Income, and label', fontsize=16)
plt.xlabel('Age')
plt.ylabel('Annual Income')
plt.show()

# %%
# Check the distribution of gender for approved and denied applications
sns.countplot(data=df, x='GENDER', hue='Target')
# Out:
# <Axes: xlabel='GENDER', ylabel='count'>

# %%
# Check the distribution of education for approved and denied applications
plt.figure(figsize=(12, 8))
sns.countplot(data=df, x='EDUCATION', hue='Target')
plt.show()

# %%
# Check the distribution of income for approved and denied applications
fig, ax = plt.subplots(figsize=(10, 8))  
sns.histplot(data=df, x="Annual_income", hue="Target", kde=True, ax=ax)

plt.title("Annual_income Distribution")
plt.xlabel("Annual_income")
plt.ylabel("Count")

plt.show()

# %%
# Explore the distribution of categorical features
# Check the distribution of Marital_status for approved and denied applications
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Marital_status', hue='Target')
plt.show()

# %%
# Check the distribution of Type_Occupation for approved and denied applications
plt.figure(figsize=(18, 10))
sns.countplot(data=df, x='Type_Occupation', hue='Target')
plt.show()

# %%
# Create pairwise scatter plots of numerical features
sns.pairplot(data=df, hue='Target', diag_kind='hist')
plt.show()

# %%
# Explore the distribution of categorical features among approved and denied applications
cat_vars = ['GENDER', 'Car_Owner', 'Propert_Owner', 'CHILDREN', 'Type_Income', 'EDUCATION', 'Marital_status', 'Housing_type']
for var in cat_vars:
    g = sns.catplot(x=var, col='label', data=df, kind='count', height=4, aspect=0.7)
    g.set_xticklabels(rotation=45)
    plt.show()

# %%
# Explore the distribution of numerical features among approved and denied applications
num_vars = ['Annual_income', 'Employed_days', 'Family_Members', 'age']
for var in num_vars:
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='label', y=var, data=df)
    plt.show()

# %%
# Create a pair plot
sns.pairplot(df, 
             vars=["Marital_status", "EDUCATION", "Propert_Owner", "Type_Occupation"], 
             hue="label",
             hue_order=[0,1],
             diag_kind="hist",
             height =3)

# %%
# Binning the Age column 
bins = [0, 25, 40, 60, 100]
labels = ['Young', 'Adult', 'Middle-Age', 'Elderly']
df['age'] = pd.cut(df['age'], bins=bins, labels=labels)

# %%
# Check the distribution of age for approved and denied applications
sns.histplot(data=df, x='age', hue='Target')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# ### **Feature Engineering**

# %%
# One-hot encode the categorical features
cat_features = ["GENDER", "Car_Owner", "Propert_Owner", "Type_Income", "EDUCATION", "Marital_status", "Housing_type", "Type_Occupation", "Target", "age"]
df = pd.get_dummies(df, columns=cat_features)

# %%
# Calculate the percentage value of every column
for column in df.columns:
    print(column, ':', round(df[column].value_counts(normalize=True) * 100, 2), '%')
# Out:
# Streaming output truncated to the last 5000 lines.
# 5126311    0.06
# 5115633    0.06
# 5024163    0.06
# 5114342    0.06
# 5053182    0.06
# 5090335    0.06
# 5036648    0.06
# 5090126    0.06
# 5090871    0.06
# 5067542    0.06
# 5139823    0.06
# 5041681    0.06
# 5115884    0.06
# 5116613    0.06
# 5022025    0.06
# 5035859    0.06
# 5021490    0.06
# 5132569    0.06
# 5091824    0.06
# 5029251    0.06
# 5033906    0.06
# 5139761    0.06
# 5142496    0.06
# 5035682    0.06
# 5079016    0.06
# 5023092    0.06
# 5041520    0.06
# 5066832    0.06
# 5137385    0.06
# 5067281    0.06
# 5045113    0.06
# 5117331    0.06
# 5010303    0.06
# 5046398    0.06
# 5096169    0.06
# 5022015    0.06
# 5117716    0.06
# 5009845    0.06
# 5024103    0.06
# 5149592    0.06
# 5135946    0.06
# 5046086    0.06
# 5033831    0.06
# 5028726    0.06
# 5062594    0.06
# 5097170    0.06
# 5125585    0.06
# 5009586    0.06
# 5091718    0.06
# 5047667    0.06
# 5022954    0.06
# 5022118    0.06
# ...

# %%
# Compute the correlation matrix
corr = df.corr()

# Create a larger figure
plt.figure(figsize=(58, 28))

# Plot the correlation heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation heatmap')
plt.show()

# %%
# Scale numerical features
scaler = StandardScaler()
num_cols = ["Birthday_count", "Employed_days", "Annual_income", "Family_Members"]
df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df['Target'] = df['label'].apply(get_label_for_data)

# %%
#get the day of birth for each person   
df['BIRTH_DAY']   = df['Birthday_count'].apply(calc_day_of_birth)

# %%
#get the day of employment for each person   
df['EMPLOYED_DAY']   = df['Employed_days'].apply(calc_day_of_employed)

# %%
print(df.head())
# Out:
#     Ind_ID CHILDREN  Annual_income  Birthday_count  Employed_days Work_Phone  \
# 0  5008827        0      -0.093813       -0.617666       2.220314          0
# 1  5009744        0       1.105349        0.603545      -0.435171          1
# 2  5009746        0       1.105349       -1.526959      -0.435171          1
# 3  5009749        0      -0.493534        0.603545      -0.435171          1
# 4  5009752        0       1.105349        0.603545      -0.435171          1
#
#   Phone EMAIL_ID  Family_Members label  ... Type_Occupation_Sales staff  \
# 0     0        0       -0.170453     1  ...                           0
# 1     1        0       -0.170453     1  ...                           0
# 2     1        0       -0.170453     1  ...                           0
# 3     1        0       -0.170453     1  ...                           0
# 4     1        0       -0.170453     1  ...                           0
#
#   Type_Occupation_Secretaries  Type_Occupation_Security staff  \
# ...

# %%
df['label'].value_counts()
# Out:
# 0    1373
# 1     175
# Name: label, dtype: int64

# %%
df.head()
# Out:
#     Ind_ID CHILDREN  Annual_income  Birthday_count  Employed_days Work_Phone  \
# 0  5008827        0      -0.093813       -0.617666       2.220314          0
# 1  5009744        0       1.105349        0.603545      -0.435171          1
# 2  5009746        0       1.105349       -1.526959      -0.435171          1
# 3  5009749        0      -0.493534        0.603545      -0.435171          1
# 4  5009752        0       1.105349        0.603545      -0.435171          1
#
#   Phone EMAIL_ID  Family_Members label  ... Type_Occupation_Sales staff  \
# 0     0        0       -0.170453     1  ...                           0
# 1     1        0       -0.170453     1  ...                           0
# 2     1        0       -0.170453     1  ...                           0
# 3     1        0       -0.170453     1  ...                           0
# 4     1        0       -0.170453     1  ...                           0
#
#   Type_Occupation_Secretaries  Type_Occupation_Security staff  \
# ...
